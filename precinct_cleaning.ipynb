# %%
import pdfplumber
import pandas as pd
import re
import os
import geopandas as gpd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
precincts = []

# %%
for file in os.listdir('precinct'):
    if file.endswith('pdf'):
        curr_file = 'precinct/' + file
        curr_year = int(re.search(r'\d{4}', file).group(0))
        data = []
        with pdfplumber.open(curr_file) as pdf:
            for page in pdf.pages:
                text = page.extract_text()
                for line in text.split('\n'):
                    if line.strip():
                        data.append(line)
        new_df = []
        i = 0
        while i < len(data):
            line = data[i]
            if re.match(r"^\d{4}\s[A-Z]+", line):
                curr_district = ' '.join(line.split(' ')[1:])
                i += 2
                if data[i].startswith('REGISTERED VOTERS - TOTAL'):
                    registered_voters = int(data[i].split()[-1])
                    i += 1
                if data[i].startswith('BALLOTS CAST - TOTAL'):
                    ballots_cast = int(data[i].split()[-1])
                    i += 1
                if data[i].startswith('VOTER TURNOUT - TOTAL'):
                    voter_turnout = float(data[i].split()[-1])
                    i += 1
                new_df.append({
                    'district': curr_district,
                    'registered_voters': registered_voters,
                    'ballots_cast': ballots_cast,
                    'voter_turnout': voter_turnout
                })
            i+=1
        new_df = pd.DataFrame(new_df)
        new_df['year'] = curr_year
        new_df['is_midterm'] = curr_year % 4 != 0
        precincts.append(pd.DataFrame(new_df))

# %%
for file in os.listdir('precinct'):
    if file.endswith('csv'):
        curr_file = 'precinct/' + file
        curr_df = pd.read_csv(curr_file)
        curr_year = int(file.split('_')[1].split('.')[0])
        curr_df = curr_df.rename(columns={
            'Precinct': 'district',
            'County': 'district',
            'Registered Voters': 'registered_voters',
            'Ballots Cast': 'ballots_cast',
            'Voter Turnout': 'voter_turnout'
        })
        curr_df['year'] = curr_year
        curr_df['district'] = curr_df['district'].str.upper()
        curr_df['voter_turnout'] = curr_df['voter_turnout'].str.replace('%', '').astype(float)
        if curr_year % 4 != 0:
            curr_df['is_midterm'] = True
        else:
            curr_df['is_midterm'] = False
        try:
            precincts.append(curr_df[['district', 'registered_voters', 'ballots_cast', 'voter_turnout', 'year', 'is_midterm']])
        except:
            display(curr_df.head())

precincts_df = pd.concat(precincts).sort_values(by=['year', 'district'])

# %%
precincts_df[precincts_df['district'] == 'ALEPPO']
# Out:
#   district  registered_voters  ballots_cast  voter_turnout  year  is_midterm
# 0   ALEPPO               1461          1073          73.44  2008       False
# 0   ALEPPO               1411           824          58.40  2010        True
# 0   ALEPPO               1390           984          70.79  2012       False
# 0   ALEPPO               1370           698          50.95  2014        True
# 0   ALEPPO               1373          1036          75.46  2016       False
# 0   ALEPPO               1374           891          64.85  2018        True
# 0   ALEPPO               1388          1121          80.76  2020       False
# 0   ALEPPO               1379           987          71.57  2022        True
# 0   ALEPPO               1363          1128          82.76  2024       False

# %%
precincts_df.to_csv('total_precincts.csv')

relevant_districts_2024 = precincts_df[precincts_df['year'] == 2024]['district'].unique()
relevant_districts_2014 = precincts_df[precincts_df['year'] == 2014]['district'].unique()

relevant_districts = set(relevant_districts_2024).intersection(set(relevant_districts_2014))

relevant_df = precincts_df[precincts_df['district'].isin(relevant_districts)]

# %%
allegheny_districts = gpd.read_file('voting_districts.geojson')
allegheny_districts['Muni_War_1'] = allegheny_districts['Muni_War_1'].str.upper()
relevant_df = relevant_df.merge(allegheny_districts, left_on='district', right_on='Muni_War_1', how='left')
relevant_df
# Out:
#                         district  registered_voters  ballots_cast  \
# 0                         ALEPPO               1461          1073
# 1               ASPINWALL DIST 1                910           644
# 2               ASPINWALL DIST 2                651           448
# 3               ASPINWALL DIST 3                882           602
# 4                  AVALON WARD 1               1144           700
# ...                          ...                ...           ...
# 10162  WILKINSBURG WARD 3 DIST 4               1061           705
# 10163  WILKINSBURG WARD 3 DIST 5               1090           656
# 10164  WILKINSBURG WARD 3 DIST 6                516           269
# 10165          WILMERDING DIST 1                481           248
# 10166          WILMERDING DIST 2                695           437
#
#        voter_turnout  year  is_midterm  OBJECTID         NAME      TYPE  \
# 0              73.44  2008       False        19       ALEPPO  TOWNSHIP
# 1              70.77  2008       False        47    ASPINWALL   BOROUGH
# 2              68.82  2008       False       672    ASPINWALL   BOROUGH
# 3              68.25  2008       False       682    ASPINWALL   BOROUGH
# 4              61.19  2008       False       485       AVALON   BOROUGH
# ...              ...   ...         ...       ...          ...       ...
# 10162          66.45  2024       False       798  WILKINSBURG   BOROUGH
# 10163          60.18  2024       False       781  WILKINSBURG   BOROUGH
# 10164          52.13  2024       False       785  WILKINSBURG   BOROUGH
# 10165          51.56  2024       False       894   WILMERDING   BOROUGH
# 10166          62.88  2024       False       435   WILMERDING   BOROUGH
#
#                      LABEL  ...  MWD_NOPA_1  OPA_MUNI_1  MWD_PAD_1 Pseud4_12  \
# 0          Aleppo Township  ...       10101         901    1010001      0001
# 1        Aspinwall Borough  ...       10201         801    1020001      0002
# 2        Aspinwall Borough  ...       10202         801    1020002      0003
# 3        Aspinwall Borough  ...       10203         801    1020003      0004
# 4           Avalon Borough  ...       10310         802    1030100      0005
# ...                    ...  ...         ...         ...        ...       ...
# 10162  Wilkinsburg Borough  ...       22834         866    2280304      1318
# 10163  Wilkinsburg Borough  ...       22835         866    2280305      1319
# 10164  Wilkinsburg Borough  ...       22836         866    2280306      1320
# 10165   Wilmerding Borough  ...       22901         867    2290001      1321
# 10166   Wilmerding Borough  ...       22902         867    2290002      1322
#
#        PseudoNu_5                 Muni_War_1   Shape__Area  Shape__Length  \
# 0               1                     ALEPPO  4.944878e+07   43972.637115
# 1               2           ASPINWALL DIST 1  4.794887e+06   10563.280842
# 2               3           ASPINWALL DIST 2  3.365936e+06    7455.357920
# 3               4           ASPINWALL DIST 3  2.642739e+06    6554.334509
# 4               5              AVALON WARD 1  5.197085e+06   12207.108951
# ...           ...                        ...           ...            ...
# 10162        1318  WILKINSBURG WARD 3 DIST 4  2.179915e+06    6971.000305
# 10163        1319  WILKINSBURG WARD 3 DIST 5  4.452737e+06    9573.866657
# 10164        1320  WILKINSBURG WARD 3 DIST 6  2.323231e+06    8257.952197
# 10165        1321          WILMERDING DIST 1  5.853308e+06   14090.529156
# 10166        1322          WILMERDING DIST 2  6.113457e+06   12791.431324
#
#       RotateMap                                           geometry
# 0            90  POLYGON ((-80.15974 40.54168, -80.15974 40.541...
# 1             0  POLYGON ((-79.90141 40.4858, -79.90168 40.4858...
# 2             0  POLYGON ((-79.90215 40.49978, -79.90214 40.499...
# 3             0  POLYGON ((-79.89682 40.49301, -79.89685 40.492...
# 4             0  POLYGON ((-80.06724 40.50315, -80.06714 40.503...
# ...         ...                                                ...
# 10162         0  POLYGON ((-79.8878 40.44049, -79.88795 40.4404...
# 10163         0  POLYGON ((-79.89238 40.45026, -79.89204 40.450...
# 10164        90  POLYGON ((-79.88409 40.44915, -79.88407 40.449...
# 10165        90  POLYGON ((-79.81408 40.4006, -79.81407 40.4006...
# 10166         0  POLYGON ((-79.80494 40.39371, -79.80476 40.393...
#
# [10167 rows x 23 columns]

# %%
gpd.GeoDataFrame(relevant_df).to_file('relevant_precincts.geojson', driver='GeoJSON')
